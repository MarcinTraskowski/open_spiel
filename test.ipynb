# %% [markdown]
# to check playthrough
#
# python3 open_spiel/python/examples/playthrough.py --game patrol

# %%
import pyspiel
import time

from open_spiel.python.algorithms import cfr
#from open_spiel.python import games
from open_spiel.python.algorithms import exploitability


game = pyspiel.load_game("patrol")
solver = cfr.CFRSolver(game)

start = time.time()
for i in range(1000):
    solver.evaluate_and_update_policy()
end = time.time()
print(f"Elapsed: {end - start:.2f} seconds")


policy = solver.average_policy()

for state in policy.states:
    probs = policy.action_probabilities(state)
    print(state.information_state_string(state.current_player()), probs)


#conv = exploitability.exploitability(game, solver.average_policy())
# Out:
# Optional module pokerkit_wrapper was not importable: No module named 'pokerkit'
# Elapsed: 33.35 seconds
# D|(0,) {0: np.float64(0.9967425219758546), 1: np.float64(0.0032574780241455283)}
# D|(0, 0) {0: np.float64(0.0034583321917175743), 1: np.float64(0.9965416678082825)}
# D|(0, 1) {0: np.float64(0.0003036878958698501), 1: np.float64(0.0003036878958698501), 2: np.float64(0.9993926242082604)}
# D|(1, 1) {0: np.float64(0.3333333333333333), 1: np.float64(0.3333333333333333), 2: np.float64(0.3333333333333333)}
# D|(1, 2) {1: np.float64(0.9992344849700442), 2: np.float64(0.0007655150299557358)}
# D|(1, 0) {0: np.float64(0.0009351553311338719), 1: np.float64(0.999064844668866)}
# D|(2, 1) {0: np.float64(0.996905163072233), 1: np.float64(0.00038131521398345104), 2: np.float64(0.0027135217137836203)}
# D|(2, 2) {1: np.float64(0.9965494365768937), 2: np.float64(0.0034505634231063362)}
# D|(1,) {0: np.float64(0.8422609163679137), 1: np.float64(0.0006666666666666609), 2: np.float64(0.15707241696541974)}
# D|(2,) {1: np.float64(0.001), 2: np.float64(0.999)}
# A|(0, 0) {0: np.float64(0.33333333333333337), 1: np.float64(0.33333333333333337), 2: np.float64(0.33333333333333337)}
# A|(0, 1) {0: np.float64(0.4993333333333333), 1: np.float64(0.4993333333333333), 2: np.float64(0.0013333333333333333)}
# A|(1, 0) {0: np.float64(0.33333333333333337), 1: np.float64(0.33333333333333337), 2: np.float64(0.33333333333333337)}
# A|(1, 1) {0: np.float64(0.33333333333333337), 1: np.float64(0.33333333333333337), 2: np.float64(0.33333333333333337)}
# A|(1, 2) {0: np.float64(0.9143762992119452), 1: np.float64(0.0006666666666666751), 2: np.float64(0.08495703412138815)}
# A|(2, 1) {0: np.float64(0.7702340520902919), 1: np.float64(0.2290992812430414), 2: np.float64(0.000666666666666663)}
# A|(2, 2) {0: np.float64(0.33333333333333337), 1: np.float64(0.33333333333333337), 2: np.float64(0.33333333333333337)}

# %%
import pyspiel
import random

game = pyspiel.load_game("patrol")
state = game.new_initial_state()

random.seed(42)

print("Game:", game)
print("Initial state:", state)
print("-" * 40)

while not state.is_terminal():
    player = state.current_player()

    print("Player:", player)
    print("State:", state)

    if player == pyspiel.PlayerId.CHANCE:
        outcomes = state.chance_outcomes()
        print("Chance outcomes:", outcomes)

        actions, probs = zip(*outcomes)
        action = random.choices(actions, probs)[0]

    else:
        actions = state.legal_actions()
        print("Legal actions:", actions)

        action = random.choice(actions)

    print("Chosen action:", action)
    state.apply_action(action)
    print("-" * 40)

print("Terminal reached")
print("Returns:", state.returns())
# Out:
# Game: patrol()
# Initial state: [chance] pos=None, hist=[], attack=None, t=0
# ----------------------------------------
# Player: -1
# State: [chance] pos=None, hist=[], attack=None, t=0
# Chance outcomes: [(0, 0.3333333333333333), (1, 0.3333333333333333), (2, 0.3333333333333333)]
# Chosen action: 1
# ----------------------------------------
# Player: 0
# State: [defender] pos=1, hist=[1], attack=None, t=0
# Legal actions: [0, 1, 2]
# Chosen action: 0
# ----------------------------------------
# Player: 0
# State: [defender] pos=0, hist=[1, 0], attack=None, t=0
# Legal actions: [0, 1, 2]
# Chosen action: 2
# ----------------------------------------
# Player: 1
# State: [attacker] pos=2, hist=[1, 0, 2], attack=None, t=0
# Legal actions: [0, 1, 2]
# Chosen action: 1
# ----------------------------------------
# Player: 0
# State: [defender] pos=2, hist=[1, 0, 2], attack=1, t=3
# Legal actions: [0, 1, 2]
# Chosen action: 0
# ----------------------------------------
# Player: 0
# State: [defender] pos=0, hist=[1, 0, 2, 0], attack=1, t=2
# Legal actions: [0, 1, 2]
# Chosen action: 0
# ----------------------------------------
# Player: 0
# State: [defender] pos=0, hist=[1, 0, 2, 0, 0], attack=1, t=1
# Legal actions: [0, 1, 2]
# Chosen action: 0
# ----------------------------------------
# Terminal reached
# Returns: [-1.0, 1.0]

# %%
import pyspiel
import time

from open_spiel.python.algorithms import cfr
#from open_spiel.python import games
from open_spiel.python.algorithms import exploitability


game = pyspiel.load_game("kuhn_poker")

cfr_solver = cfr.CFRSolver(game)
iterations = 10000

start = time.time()
for i in range(iterations):
    cfr_value = cfr_solver.evaluate_and_update_policy()
    
end = time.time()
print(f"Elapsed: {end - start:.2f} seconds")
# Out:
# Optional module pokerkit_wrapper was not importable: No module named 'pokerkit'
# Elapsed: 10.72 seconds
