# %%
import pyspiel
print(pyspiel.__file__)
# Out:
# /home/marcin_traskowski/open_spiel/pyspiel.so

# %%
import pyspiel

game = pyspiel.load_game("patrol")

# %%
import pyspiel
import random

game = pyspiel.load_game("patrol")
state = game.new_initial_state()

while not state.is_terminal():
    print(state)
    if state.current_player() >= 0:
        print("infostate:", state.information_state_string(state.current_player()))
    print("player:", state.current_player())
    actions = state.legal_actions()
    print("actions:", actions)

    action = random.choice(actions)
    print("chosen:", action)

    state.apply_action(action)
    print()

print("returns:", state.returns())
# Out:
# phase=chance pos=-1 target=-1 remaining=-1 step=0 delay=-1
# player: -1
# actions: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# chosen: 5
#
# phase=defender pos=1 target=-1 remaining=-1 step=0 delay=2
# infostate: p=0|pos=1
# player: 0
# actions: [0, 1, 2]
# chosen: 1
#
# phase=defender pos=1 target=-1 remaining=-1 step=1 delay=2
# infostate: p=0|pos=1
# player: 0
# actions: [0, 1, 2]
# chosen: 1
#
# phase=attacker pos=1 target=-1 remaining=-1 step=2 delay=2
# infostate: p=1|pos=1
# player: 1
# actions: [0, 1, 2]
# chosen: 2
#
# phase=defender pos=1 target=2 remaining=3 step=2 delay=2
# infostate: p=0|pos=1
# player: 0
# actions: [0, 1, 2]
# chosen: 0
#
# phase=defender pos=0 target=2 remaining=2 step=3 delay=2
# infostate: p=0|pos=0
# player: 0
# actions: [0, 1, 2]
# chosen: 1
#
# phase=defender pos=1 target=2 remaining=1 step=4 delay=2
# infostate: p=0|pos=1
# player: 0
# actions: [0, 1, 2]
# chosen: 2
#
# returns: [-3.0, 3.0]

# %%
import pyspiel
import time
from open_spiel.python.algorithms import cfr

game = pyspiel.load_game("patrol")  #  C++ game loaded in Python
solver = cfr.CFRSolver(game)

start = time.time()
for i in range(1000):
    solver.evaluate_and_update_policy()
end = time.time()
print(f"Time taken: {end - start}")

policy = solver.average_policy()

for state in policy.states:
    print(state, policy.action_probabilities(state))
# Out:
# Optional module pokerkit_wrapper was not importable: No module named 'pokerkit'
# Time taken: 25.754018783569336
# phase=defender pos=0 target=-1 remaining=-1 step=0 delay=0 {0: np.float64(0.00034262952785471556), 1: np.float64(0.7041457267487327), 2: np.float64(0.2955116437234127)}
# phase=defender pos=2 target=1 remaining=1 step=2 delay=0 {0: np.float64(0.549988039822891), 1: np.float64(0.449559256051687), 2: np.float64(0.000452704125422116)}
# phase=defender pos=1 target=2 remaining=1 step=3 delay=0 {0: np.float64(0.5274698593883156), 1: np.float64(0.00035406962536890004), 2: np.float64(0.4721760709863154)}
# phase=attacker pos=0 target=-1 remaining=-1 step=1 delay=0 {0: np.float64(0.0004709350617843693), 1: np.float64(0.8030712232817773), 2: np.float64(0.19645784165643837)}
# phase=attacker pos=1 target=-1 remaining=-1 step=1 delay=0 {0: np.float64(0.6984170243753338), 1: np.float64(0.0006666666666666695), 2: np.float64(0.3009163089579995)}
# phase=attacker pos=2 target=-1 remaining=-1 step=1 delay=0 {0: np.float64(0.06225981514992693), 1: np.float64(0.9374068515167397), 2: np.float64(0.0003333333333333325)}
